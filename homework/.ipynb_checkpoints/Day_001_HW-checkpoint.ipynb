# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    """
    請完成這個 Function 後往下執行
    """
    minus = y - y_hat
    minus_square = minus ** 2
    all_sum = minus_square.sum()
    n = y.size
    mse = all_sum / n
    return mse

# %%
def mean_absolute_error(y, y_hat):
    minus = y - y_hat
    minus = abs(minus)
    minus_square = minus ** 2
    all_sum = minus_square.sum()
    n = y.size
    mse = all_sum / n
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 277.742
# The Mean absolute error is 277.742

# %% [markdown]
# #### [Find from Web](https://stackoverflow.com/questions/39064684/mean-squared-error-in-python?rq=1)
# mse = np.mean((y - y_hat)**2)

# %% [markdown]
# #### 作業1:
# [Digit Recognizer](https://www.kaggle.com/c/digit-recognizer/data)
# 1. 你選的這組資料為何重要
# > 這組資料就等同是機器學習的"Hello World!"
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# > 手寫的圖片
# 3. 蒐集而來的資料型態為何
# > 每張圖片為28 pixels X 28 pixels<br/>
# > 每pixel的值為0~255(值越大顏色越深)
# 4. 這組資料想解決的問題如何評估
# > 可以辨識手寫從0~9的數字，延伸後即可辨識一整張圖片的數字

# %% [markdown]
# #### 作業2
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# > 提升業績最直接的方法為增加乘客數，透過收集里程數來換取點數，來吸引乘客。 <br />
# > 假設民眾對於搭車可以順便收集點數會有興趣。
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# > 以問卷調查收集資料
# 3. 蒐集而來的資料型態為何
# > 選項為數值型態 <br />
# > 其他建議為文字型態
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# > 以願意填選問卷的比例做為對此活動的感興趣程度 <br />
# > 將選項轉為數值統計是否對這活動贊同
